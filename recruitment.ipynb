# %% [markdown]
# # Recruitment Predictor
#
# We are about to build a **Recruitment Predictor** using the **`recruitment_data.csv`** dataset from Kaggle.
#
# Our goal is to train a model that predicts recruitment outcomes from candidate/application data.
#
# ## What we will do
# 1. Load and inspect the dataset.
# 2. Clean and preprocess the data.
# 3. Perform exploratory data analysis (EDA).
# 4. Train and evaluate prediction models.
# 5. Select the best model and interpret results.

# %%
import pandas as pd

data_path = 'recruitment_data.csv'
df = pd.read_csv(data_path)
df.head()

# %%
print('Shape:', df.shape)
print('\nColumn types:')
display(df.dtypes)

print('\nMissing values per column:')
display(df.isna().sum().sort_values(ascending=False))
